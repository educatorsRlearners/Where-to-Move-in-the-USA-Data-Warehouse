# %%
from constants import STORE_COLUMNS, INTERNET_SPEED_COLUMNS, STORES_TABLE, INTERNET_SPEED_TABLE
from create_tables import create_tables 
from get_data.get_trader_joes import create_dataframe 
from insert_data import upsert_dataframe_batch

# %%
command = open("sql/create_stores.sql", "r").read()
create_tables(command)
# Out:
# Connected to the PostgreSQL server.
# Table created successfully.
# Database connection closed.

# %%
df = create_dataframe()
# Out:
# Total stores found: 647

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store_number  647 non-null    str
#  1   store_name    647 non-null    str
#  2   street        647 non-null    str
#  3   city          647 non-null    str
#  4   state         647 non-null    str
#  5   zip_code      647 non-null    str
#  6   phone_number  647 non-null    str
#  7   url           647 non-null    str
# dtypes: str(8)
# memory usage: 40.6 KB

# %% [markdown]
# ### Add the data

# %%
upsert_dataframe_batch(df=df, table_name="stores", conflict_column="url", columns=STORE_COLUMNS)
# Out:
# Connected. Processing 647 rows in batches of 1000...
#   Batch 1: 647 rows
# ✅ Completed: 647 total rows upserted
# 647

# %%
from get_data.get_internet_speeds import get_internet_speeds_df

df = get_internet_speeds_df()

# %%
df.head()
# Out:
#      Zip  Population     County           State  WiredCount_2020  \
# 0  29620     12934.0  Abbeville  South Carolina              6.0
# 1  29628      2759.0  Abbeville  South Carolina              4.0
# 2  29638      2944.0  Abbeville  South Carolina              6.0
# 3  29639      1742.0  Abbeville  South Carolina              3.0
# 4  70516      1546.0     Acadia       Louisiana              4.0
#
#    Fwcount_2020  AllProviderCount_2020  Wired25_3_2020  Wired100_3_2020  \
# 0           0.0                   11.0             5.0              3.0
# 1           0.0                    8.0             3.0              2.0
# 2           1.0                   13.0             4.0              4.0
# 3           0.0                    8.0             3.0              3.0
# 4           3.0                   12.0             2.0              2.0
#
#    All25_3_2020  ...  FastestAverageMbps  %Access to Terrestrial Broadband  \
# 0           7.0  ...              536.35                               98%
# 1           5.0  ...              126.06                               95%
# 2           6.0  ...              222.35                               95%
# 3           5.0  ...              223.75                               90%
# 4           4.0  ...                9.41                               33%
#
#    Lowest Priced Terrestrial Broadband Plan  WiredCount_2015 Fwcount_2015  \
# 0                                     40.00              6.0          0.0
# 1                                     40.00              4.0          0.0
# 2                                     40.00              5.0          0.0
# 3                                     40.00              3.0          0.0
# 4                                     69.99              4.0          2.0
#
#    AllProviderCount_2015  Wired25_3_2015  Wired100_3_2015  All25_3_2015  \
# 0                    8.0             3.0              3.0           3.0
# 1                    6.0             3.0              3.0           3.0
# 2                    7.0             2.0              2.0           2.0
# 3                    5.0             3.0              3.0           3.0
# 4                    8.0             2.0              1.0           2.0
#
#    All100_3.1
# 0         3.0
# 1         3.0
# 2         2.0
# 3         3.0
# 4         1.0
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32608 entries, 0 to 32607
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Zip                                       32608 non-null  str
#  1   Population                                29727 non-null  float64
#  2   County                                    32608 non-null  str
#  3   State                                     32608 non-null  str
#  4   WiredCount_2020                           29733 non-null  float64
#  5   Fwcount_2020                              29733 non-null  float64
#  6   AllProviderCount_2020                     29733 non-null  float64
#  7   Wired25_3_2020                            29733 non-null  float64
#  8   Wired100_3_2020                           29733 non-null  float64
#  9   All25_3_2020                              29733 non-null  float64
#  10  All100_3                                  29733 non-null  float64
#  11  TestCount                                 26368 non-null  float64
#  12  AverageMbps                               26368 non-null  float64
#  13  FastestAverageMbps                        26368 non-null  float64
#  14  %Access to Terrestrial Broadband          29685 non-null  str
#  15  Lowest Priced Terrestrial Broadband Plan  26630 non-null  float64
#  16  WiredCount_2015                           29730 non-null  float64
#  17  Fwcount_2015                              29730 non-null  float64
#  18  AllProviderCount_2015                     29730 non-null  float64
#  19  Wired25_3_2015                            29730 non-null  float64
#  20  Wired100_3_2015                           29730 non-null  float64
#  21  All25_3_2015                              29730 non-null  float64
#  22  All100_3.1                                29730 non-null  float64
# dtypes: float64(19), str(4)
# memory usage: 5.7 MB

# %%
upsert_dataframe_batch(df=df, table_name=INTERNET_SPEED_TABLE, conflict_column="zip", columns=INTERNET_SPEED_COLUMNS)
# Out:
# Connected. Processing 32608 rows in batches of 1000...
# ❌ Error: "None of [Index(['zip', 'population', 'county', 'state', 'wiredcount_2020',\n       'fwcount_2020', 'allprovidercount_2020', 'wired25_3_2020',\n       'wired100_3_2020', 'all25_3_2020', 'all100_3_2020', 'testcount',\n       'averagembps', 'fastestaveragembps', 'access_terrestrial_broadband',\n       'lowest_priced_terrestrial_broadband', 'wiredcount_2015',\n       'fwcount_2015', 'allprovidercount_2015', 'wired25_3_2015',\n       'wired100_3_2015', 'all25_3_2015', 'all100_3_1'],\n      dtype='str')] are in the [columns]"
# 0
