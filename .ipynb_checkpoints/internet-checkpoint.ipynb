# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/BroadbandNow/Open-Data/master/broadband_data_opendatachallenge.csv'
df = pd.read_csv(url, encoding='latin-1')
df.to_csv('data/raw/internet.csv', index=False)

# https://github.com/BroadbandNow/Open-Data

# %%
df.head()
# Out:
#      Zip  Population     County           State  WiredCount_2020  \
# 0  29620     12934.0  Abbeville  South Carolina              6.0
# 1  29628      2759.0  Abbeville  South Carolina              4.0
# 2  29638      2944.0  Abbeville  South Carolina              6.0
# 3  29639      1742.0  Abbeville  South Carolina              3.0
# 4  70516      1546.0     Acadia       Louisiana              4.0
#
#    Fwcount_2020  AllProviderCount_2020  Wired25_3_2020  Wired100_3_2020  \
# 0           0.0                   11.0             5.0              3.0
# 1           0.0                    8.0             3.0              2.0
# 2           1.0                   13.0             4.0              4.0
# 3           0.0                    8.0             3.0              3.0
# 4           3.0                   12.0             2.0              2.0
#
#    All25_3_2020  ...  FastestAverageMbps  %Access to Terrestrial Broadband  \
# ...

# %%
df.count()
# Out:
# Zip                                         32608
# Population                                  29727
# County                                      32608
# State                                       32608
# WiredCount_2020                             29733
# Fwcount_2020                                29733
# AllProviderCount_2020                       29733
# Wired25_3_2020                              29733
# Wired100_3_2020                             29733
# All25_3_2020                                29733
# All100_3                                    29733
# TestCount                                   26368
# AverageMbps                                 26368
# FastestAverageMbps                          26368
# %Access to Terrestrial Broadband            29685
# Lowest Priced Terrestrial Broadband Plan    26630
# WiredCount_2015                             29730
# Fwcount_2015                                29730
# AllProviderCount_2015                       29730
# ...

# %%
df.loc[:, ['Zip', 'AverageMbps', 'FastestAverageMbps']].sort_values(by="Zip")
# Out:
#          Zip  AverageMbps  FastestAverageMbps
# 189      601        10.93               39.45
# 190      602        83.50              232.48
# 191      603        36.87              161.04
# 17739    606         2.70                7.60
# 709      610        41.02              132.70
# ...      ...          ...                 ...
# 32552  99926         4.57                9.25
# 32553  99927          NaN                 NaN
# 32478  99928          NaN                 NaN
# 32577  99929        27.59               84.59
# 32479  99950          NaN                 NaN
#
# [32608 rows x 3 columns]

# %%
store = pd.read_csv('store_covid.csv')
store.head()
# Out:
#                          store_name                    street           city  \
# 0       Trader Joe's Sunnyvale (68)   316 West El Camino Real      Sunnyvale
# 1    Trader Joe's Aliso Viejo (195)      26541 Aliso Creek Rd    Aliso Viejo
# 2  Trader Joe's Newport Beach (125)  8086 E Pacific Coast Hwy  Newport Beach
# 3      Trader Joe's Pleasanton (66)      3903 Santa Rita Road     Pleasanton
# 4      Trader Joe's Costa Mesa (35)             640 W 17th St     Costa Mesa
#
#   state    zip      landline        mobile  \
# 0    CA  94087  408-736-7573  408-736-7573
# 1    CA  92656  949-643-5531  949-643-5531
# 2    CA  92657  949-494-7404  949-494-7404
# 3    CA  94588  925-468-0763  925-468-0763
# 4    CA  92627  949-642-5134  949-642-5134
#
#                                              website        date    location  \
# 0  https://locations.traderjoes.com/ca/sunnyvale/68/  2021-07-07  California
# 1  https://locations.traderjoes.com/ca/aliso-viej...  2021-07-07  California
# ...

# %%
keep = ['Zip', 'AverageMbps', 'FastestAverageMbps']

df = df.loc[:, keep]

df_merge = pd.merge(store, df, left_on='zip', right_on="Zip")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-79bececc9179> in <module>
#       3 df = df.loc[:, keep]
#       4
# ----> 5 df_merge = pd.merge(store, df, left_on='zip', right_on="Zip")
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# ...

# %%
df_merge.head()
# Out:
#                          store_name                    street           city  \
# 0       Trader Joe's Sunnyvale (68)   316 West El Camino Real      Sunnyvale
# 1    Trader Joe's Aliso Viejo (195)      26541 Aliso Creek Rd    Aliso Viejo
# 2  Trader Joe's Newport Beach (125)  8086 E Pacific Coast Hwy  Newport Beach
# 3      Trader Joe's Pleasanton (66)      3903 Santa Rita Road     Pleasanton
# 4      Trader Joe's Costa Mesa (35)             640 W 17th St     Costa Mesa
#
#   state    zip      landline        mobile  \
# 0    CA  94087  408-736-7573  408-736-7573
# 1    CA  92656  949-643-5531  949-643-5531
# 2    CA  92657  949-494-7404  949-494-7404
# 3    CA  94588  925-468-0763  925-468-0763
# 4    CA  92627  949-642-5134  949-642-5134
#
#                                              website       date    location  \
# 0  https://locations.traderjoes.com/ca/sunnyvale/68/ 2021-07-07  California
# 1  https://locations.traderjoes.com/ca/aliso-viej... 2021-07-07  California
# ...

# %%
# df_merge.to_csv('store_covid.csv', index=False)
