# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/us_state_vaccinations.csv'
df = pd.read_csv(url)
df.to_csv('data/covid/raw/state.csv', index=False)

# %%
# !mkdir data/covid
# !mkdir data/covid/raw 
# !mkdir data/covid/transformed
# !mkdir data/covid/final

# %%
df[df.location=="Alabama"]
# Out:
#            date location  total_vaccinations  total_distributed  \
# 0    2021-01-12  Alabama             78134.0           377025.0
# 1    2021-01-13  Alabama             84040.0           378975.0
# 2    2021-01-14  Alabama             92300.0           435350.0
# 3    2021-01-15  Alabama            100567.0           444650.0
# 4    2021-01-16  Alabama                 NaN                NaN
# ..          ...      ...                 ...                ...
# 172  2021-07-03  Alabama           3381996.0          4845190.0
# 173  2021-07-04  Alabama           3382042.0          4845190.0
# 174  2021-07-05  Alabama                 NaN                NaN
# 175  2021-07-06  Alabama           3392366.0          4845190.0
# 176  2021-07-07  Alabama           3396338.0          4845190.0
#
#      people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0              70861.0                                 0.15
# 1              74792.0                                 0.19
# 2              80480.0                                  NaN
# 3              86956.0                                 0.28
# 4                  NaN                                  NaN
# ..                 ...                                  ...
# 172          1969834.0                                32.89
# 173          1969971.0                                32.90
# 174                NaN                                  NaN
# 175          1976343.0                                32.99
# 176          1978951.0                                33.03
#
#      total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                              1.59                   7270.0
# 1                              1.71                   9245.0
# 2                              1.88                      NaN
# 3                              2.05                  13488.0
# 4                               NaN                      NaN
# ..                              ...                      ...
# 172                           68.98                1612803.0
# 173                           68.98                1612913.0
# 174                             NaN                      NaN
# 175                           69.19                1617584.0
# 176                           69.27                1619647.0
#
#      people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                             1.45                     7.69
# 1                             1.53                     7.73
# 2                             1.64                     8.88
# 3                             1.77                     9.07
# 4                              NaN                      NaN
# ..                             ...                      ...
# 172                          40.17                    98.82
# 173                          40.18                    98.82
# 174                            NaN                      NaN
# 175                          40.31                    98.82
# 176                          40.36                    98.82
#
#      daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                 NaN
# 1                    5906.0              5906.0
# 2                    8260.0              7083.0
# 3                    8267.0              7478.0
# 4                    7557.0              7498.0
# ..                      ...                 ...
# 172                 16373.0              9263.0
# 173                    46.0              7416.0
# 174                  5162.0              6512.0
# 175                  5162.0              6066.0
# 176                  3972.0              6533.0
#
#      daily_vaccinations_per_million  share_doses_used
# 0                               NaN             0.207
# 1                            1205.0             0.222
# 2                            1445.0             0.212
# 3                            1525.0             0.226
# 4                            1529.0               NaN
# ..                              ...               ...
# 172                          1889.0             0.698
# 173                          1512.0             0.698
# 174                          1328.0               NaN
# 175                          1237.0             0.700
# 176                          1332.0             0.701
#
# [177 rows x 14 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
oldest_date = df.date.min()
most_recent = df.date.max()

print(f'The first date in the df is {oldest_date} and the most recent is {most_recent}.')
# Out:
# The first date in the df is 2020-12-20 00:00:00 and the most recent is 2021-07-07 00:00:00.

# %%
df_sorted = (df.sort_values('date')
               .groupby('location')
               .tail(1)
               .sort_values('location')
    )

# %%
df_sorted.count()
# Out:
# date                                   65
# location                               65
# total_vaccinations                     65
# total_distributed                      64
# people_vaccinated                      64
# people_fully_vaccinated_per_hundred    61
# total_vaccinations_per_hundred         61
# people_fully_vaccinated                64
# people_vaccinated_per_hundred          61
# distributed_per_hundred                61
# daily_vaccinations_raw                 65
# daily_vaccinations                     65
# daily_vaccinations_per_million         61
# share_doses_used                       64
# dtype: int64

# %%
state_names = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", 
               "Colorado", "Connecticut", "District of Columbia", "Delaware", 
               "Florida", "Georgia", "Hawaii", "Iowa", "Idaho", "Illinois", 
               "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", 
               "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", 
               "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", 
               "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma",
               "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota",
               "Tennessee", "Texas", "Utah", "Virginia", "Vermont", "Washington", 
               "Wisconsin", "West Virginia", "Wyoming"]

state_names.sort()

state_abbr = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", 
              "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", 
              "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", 
              "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", 
              "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", 
              "WY"]

state_dict = dict(zip(state_names, state_abbr))

# thisdict["year"] = 2018

state_dict["Delaware"] = "DE"
state_dict["District of Columbia"] = "DC"


list(state_dict.items())[:5]
# Out:
# [('Alabama', 'AL'),
#  ('Alaska', 'AK'),
#  ('Arizona', 'AZ'),
#  ('Arkansas', 'AR'),
#  ('California', 'CA')]

# %%
df_filtered = df_sorted[df_sorted.location.isin(state_names)]
df_filtered.count()
# Out:
# date                                   50
# location                               50
# total_vaccinations                     50
# total_distributed                      50
# people_vaccinated                      50
# people_fully_vaccinated_per_hundred    50
# total_vaccinations_per_hundred         50
# people_fully_vaccinated                50
# people_vaccinated_per_hundred          50
# distributed_per_hundred                50
# daily_vaccinations_raw                 50
# daily_vaccinations                     50
# daily_vaccinations_per_million         50
# share_doses_used                       50
# dtype: int64

# %%
df_filtered.sort_values('people_fully_vaccinated_per_hundred', ascending=False).head()
# Out:
#             date       location  total_vaccinations  total_distributed  \
# 10288 2021-07-07        Vermont            857025.0           923760.0
# 5309  2021-07-07  Massachusetts           8912911.0          9759160.0
# 4778  2021-07-07          Maine           1627751.0          1857970.0
# 1592  2021-07-07    Connecticut           4445202.0          4731555.0
# 9026  2021-07-07   Rhode Island           1286829.0          1515025.0
#
#        people_vaccinated  people_fully_vaccinated_per_hundred  \
# 10288           463599.0                                66.13
# 5309           4885121.0                                62.23
# 4778            898741.0                                62.12
# 1592           2407644.0                                61.28
# 9026            689190.0                                59.46
#
#        total_vaccinations_per_hundred  people_fully_vaccinated  \
# 10288                          137.35                 412648.0
# 5309                           129.31                4289397.0
# 4778                           121.09                 834982.0
# 1592                           124.68                2184860.0
# 9026                           121.47                 629893.0
#
#        people_vaccinated_per_hundred  distributed_per_hundred  \
# 10288                          74.30                   148.04
# 5309                           70.88                   141.59
# 4778                           66.86                   138.22
# 1592                           67.53                   132.71
# 9026                           65.06                   143.01
#
#        daily_vaccinations_raw  daily_vaccinations  \
# 10288                   222.0               777.0
# 5309                   2800.0             10868.0
# 4778                   4131.0              3260.0
# 1592                   1337.0              5685.0
# 9026                    393.0              1539.0
#
#        daily_vaccinations_per_million  share_doses_used
# 10288                          1245.0             0.928
# 5309                           1577.0             0.913
# 4778                           2425.0             0.876
# 1592                           1595.0             0.939
# 9026                           1453.0             0.849

# %%
df_filtered.loc[:, 'state'] = df_filtered.loc[:, 'location'].map(state_dict)
# Out:
# /home/evan/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/evan/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_filtered.head()
# Out:
#            date    location  total_vaccinations  total_distributed  \
# 176  2021-07-07     Alabama           3396338.0          4845190.0
# 353  2021-07-07      Alaska            678145.0           831665.0
# 707  2021-07-07     Arizona           6830858.0          8141580.0
# 884  2021-07-07    Arkansas           2263629.0          2852450.0
# 1238 2021-07-07  California          43213547.0         49234405.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 176           1978951.0                                33.03
# 353            366305.0                                44.16
# 707           3709771.0                                43.62
# 884           1282733.0                                34.60
# 1238         24532324.0                                50.53
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
#
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 50 non-null     datetime64[ns]
#  1   location                             50 non-null     object
#  2   total_vaccinations                   50 non-null     float64
#  3   total_distributed                    50 non-null     float64
#  4   people_vaccinated                    50 non-null     float64
#  5   people_fully_vaccinated_per_hundred  50 non-null     float64
#  6   total_vaccinations_per_hundred       50 non-null     float64
#  7   people_fully_vaccinated              50 non-null     float64
#  8   people_vaccinated_per_hundred        50 non-null     float64
#  9   distributed_per_hundred              50 non-null     float64
#  10  daily_vaccinations_raw               50 non-null     float64
#  11  daily_vaccinations                   50 non-null     float64
#  12  daily_vaccinations_per_million       50 non-null     float64
#  13  share_doses_used                     50 non-null     float64
#  14  state                                50 non-null     object
# dtypes: datetime64[ns](1), float64(12), object(2)
# memory usage: 6.2+ KB

# %%
store = pd.read_csv('store_info.csv')
store.head()
# Out:
#                        store_name                   street         city state  \
# 0     Trader Joe's Sunnyvale (68)  316 West El Camino Real    Sunnyvale    CA
# 1  Trader Joe's Aliso Viejo (195)     26541 Aliso Creek Rd  Aliso Viejo    CA
# 2    Trader Joe's Brookline (501)           1317 Beacon St    Brookline    MA
# 3   Trader Joe's Park Ridge (698)         190 N NW Highway   Park Ridge    IL
# 4    Trader Joe's Scottsdale (94)     6202 N Scottsdale Rd   Scottsdale    AZ
#
#      zip      landline        mobile  \
# 0  94087  408-736-7573  408-736-7573
# 1  92656  949-643-5531  949-643-5531
# 2  02446  617-278-9997  617-278-9997
# 3  60068  847-292-1108  847-292-1108
# 4  85253  480-948-9886  480-948-9886
#
#                                              website
# 0  https://locations.traderjoes.com/ca/sunnyvale/68/
# 1  https://locations.traderjoes.com/ca/aliso-viej...
# 2  https://locations.traderjoes.com/ma/brookline/...
# 3  https://locations.traderjoes.com/il/park-ridge...
# 4  https://locations.traderjoes.com/az/scottsdale...

# %%
keep = ['date', "state", 'location', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred']

df_filtered = df_filtered.loc[:, keep]

df_merge = pd.merge(store, df_filtered, on='state')

# %%
df_merge.head()
# Out:
#                          store_name                    street           city  \
# 0       Trader Joe's Sunnyvale (68)   316 West El Camino Real      Sunnyvale
# 1    Trader Joe's Aliso Viejo (195)      26541 Aliso Creek Rd    Aliso Viejo
# 2  Trader Joe's Newport Beach (125)  8086 E Pacific Coast Hwy  Newport Beach
# 3      Trader Joe's Pleasanton (66)      3903 Santa Rita Road     Pleasanton
# 4      Trader Joe's Costa Mesa (35)             640 W 17th St     Costa Mesa
#
#   state    zip      landline        mobile  \
# 0    CA  94087  408-736-7573  408-736-7573
# 1    CA  92656  949-643-5531  949-643-5531
# 2    CA  92657  949-494-7404  949-494-7404
# 3    CA  94588  925-468-0763  925-468-0763
# 4    CA  92627  949-642-5134  949-642-5134
#
#                                              website       date    location  \
# 0  https://locations.traderjoes.com/ca/sunnyvale/68/ 2021-07-07  California
# 1  https://locations.traderjoes.com/ca/aliso-viej... 2021-07-07  California
# 2  https://locations.traderjoes.com/ca/newport-be... 2021-07-07  California
# 3  https://locations.traderjoes.com/ca/pleasanton... 2021-07-07  California
# 4  https://locations.traderjoes.com/ca/costa-mesa... 2021-07-07  California
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred
# 0                          62.09                                50.53
# 1                          62.09                                50.53
# 2                          62.09                                50.53
# 3                          62.09                                50.53
# 4                          62.09                                50.53

# %%
df_merge.to_csv('store_covid.csv', index=False)
